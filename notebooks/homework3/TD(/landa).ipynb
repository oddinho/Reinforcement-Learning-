# %%
import numpy as np

def TD_Landa(env_M, policy, gamma, alpha, n_steps, landa):
    # trying to implement TD(lambda) algorithm from psuedocode

    #need state space, action space. 
    # v == np.zeros() for whatever v is def. as
    K = 1000
    N = 1000

    for k in range(K):
        for n in range(N):
            pass

    # take action a acc to policy, 
    # ...
# Out:
#   Cell In[1], line 6
#
#     ^
# SyntaxError: incomplete input
